# %%
a=[1,3,5,7,9]
a*2

b=[2,4,6,8,10]

result=[]
for i in range(5):
    result.append(a[i]+b[i])

result
# Out:
# [3, 7, 11, 15, 19]

# %%
import numpy as np
#建立list
a = [1, 3, 5, 7, 9]
a * 2

b = [2, 4, 6, 8 ,10]
a + b

result = []
for i in range(5):
    result.append(a[i] + b[i])

result
# Out:
# [3, 7, 11, 15, 19]

# %%
import random
[random.randint(50,100) for _ in range(5)]
# Out:
# [89, 98, 92, 91, 75]

# %%
import numpy as np
np.random.randint(50,high=100,size=5)
# Out:
# array([87, 71, 79, 84, 57])

# %%
np.random.randint(50,high=100,size=(50,5))
# Out:
# array([[91, 93, 66, 99, 94],
#        [80, 50, 71, 67, 79],
#        [71, 98, 58, 97, 81],
#        [57, 61, 59, 79, 88],
#        [63, 96, 85, 53, 73],
#        [89, 96, 97, 76, 60],
#        [70, 70, 96, 83, 86],
#        [60, 97, 73, 94, 86],
#        [92, 92, 99, 59, 59],
#        [51, 53, 95, 71, 78],
#        [78, 99, 75, 71, 67],
#        [95, 75, 67, 53, 94],
#        [56, 64, 85, 60, 82],
#        [87, 65, 87, 81, 77],
#        [75, 62, 55, 98, 94],
#        [63, 87, 59, 60, 92],
#        [55, 58, 85, 89, 51],
#        [62, 95, 69, 86, 59],
#        [69, 80, 60, 69, 73],
#        [79, 97, 91, 60, 62],
#        [52, 96, 89, 99, 78],
#        [79, 73, 67, 50, 69],
#        [57, 73, 96, 65, 92],
#        [69, 94, 54, 97, 73],
#        [91, 70, 70, 54, 61],
#        [75, 64, 54, 86, 90],
#        [65, 60, 60, 57, 74],
#        [67, 68, 86, 86, 89],
#        [81, 95, 88, 61, 63],
#        [94, 51, 96, 76, 67],
#        [50, 78, 56, 80, 96],
#        [84, 66, 64, 86, 52],
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

x_array=np.linspace(-3,3,num=50)
y1_array=x_array*2+1
y2_array=x_array**2



figure = plt.figure(figsize=[8,5])
axes = figure.add_subplot()
axes.plot(x_array,y1_array)
axes.plot(x_array, y2_array)
plt.show()

# %%
import math
import matplotlib.pyplot as plt
t=np.arange(0,2.5,0.1)

y1=np.sin(math.pi*t)
y2=np.sin(math.pi*t+math.pi/2)
y3=np.sin(math.pi*t-math.pi/2)
figure = plt.figure(figsize=[8,5])
axes = figure.add_subplot()
axes.plot(y1)
axes.plot(y2)
axes.plot(y3)
plt.show()

# %%
import numpy as np
stu1=np.array([90,76,87,66,56])
stu1
# Out:
# array([90, 76, 87, 66, 56])

# %%
import pandas as pd
s1=pd.Series([90,76,87,66,56],index=['chinese', 'english', 'math', 'history', 'discover'])
s1
# Out:
# chinese     90
# english     76
# math        87
# history     66
# discover    56
# dtype: int64

# %%
s1+3
# Out:
# chinese     93
# english     79
# math        90
# history     69
# discover    59
# dtype: int64

# %%
s1["chinese"]
# Out:
# 90

# %%
for i in s1:
    print(s1)
# Out:
# chinese     90
# english     76
# math        87
# history     66
# discover    56
# dtype: int64
# chinese     90
# english     76
# math        87
# history     66
# discover    56
# dtype: int64
# chinese     90
# english     76
# math        87
# history     66
# discover    56
# dtype: int64
# chinese     90
# english     76
# math        87
# history     66
# discover    56
# dtype: int64
# chinese     90
# english     76
# math        87
# history     66
# discover    56
# dtype: int64

# %%
np.sum(s1)
# Out:
# 375

# %%
np.mean(s1)
# Out:
# 75.0

# %%
np.std(s1)
# Out:
# 12.743625857659193

# %%
np.median(s1)
# Out:
# 76.0

# %%
import pandas as pd
pd.DataFrame({"elena":[89,87,66,90,65],"jane":[99,77,56,89,80], "lenndra":[78,77,55,89,97]},
             index=['chinese', 'english', 'math', 'history', 'discover'])
# Out:
#           elena  jane  lenndra
# chinese      89    99       78
# english      87    77       77
# math         66    56       55
# history      90    89       89
# discover     65    80       97

# %%
import numpy as np
import pandas as pd

data=np.random.randint(60,high=100,size=(50,5))
pd.DataFrame(data,index=range(1,51),columns=['chinese', 'english', 'math', 'history', 'discover'])
# Out:
#     chinese  english  math  history  discover
# 1        87       63    72       83        81
# 2        87       70    77       95        67
# 3        85       93    60       65        83
# 4        87       75    96       94        75
# 5        80       63    88       71        65
# 6        61       65    80       89        82
# 7        61       99    67       70        99
# 8        97       90    93       77        62
# 9        60       73    68       60        83
# 10       72       69    64       60        72
# 11       76       80    72       61        65
# 12       81       96    84       66        86
# 13       73       79    67       87        96
# 14       64       95    95       67        84
# 15       61       95    76       75        79
# 16       95       92    69       81        82
# 17       78       72    81       93        96
# 18       87       67    94       95        70
# 19       86       63    76       97        75
# ...
